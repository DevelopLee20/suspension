# %% [markdown]
# # 계획
#
# - 데이터셋
#     - Fashion MNIST (옷 MNIST 데이터)
# - 데이터셋 비율
#     - 훈련 데이터 train-data
#         - fashion-mnist_train.csv의 70%
#     - 테스트 데이터 test-data
#         - fashion-mnist_train.csv의 30%
#     - 검증 데이터 val-data
#         - fashion-mnist_test.csv의 100%
# - 모델 model
#     - 이진분류 : 로지스틱 회귀
# - 기타
#     - 로지스틱 서드파티 라이브러리를 그대로 사용
#     - 0과 1 class만 분류

# %%
# csv 파일 데이터 로드

import pandas as pd

data1 = pd.read_csv('./dataset/fashion-mnist_train.csv')
data2 = pd.read_csv('./dataset/fashion-mnist_test.csv')

data1.shape, data2.shape
# Out:
# ((60000, 785), (10000, 785))
